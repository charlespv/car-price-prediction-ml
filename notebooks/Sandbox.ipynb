# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/Data_cars.csv')
df.head()
# Out:
#      Price     Make Model  Model_year     Mileage     Fuel      Gearbox  \
# 0  11220.0  PEUGEOT   308        2014  94341.0 km   Diesel    mécanique
# 1  57526.0      BMW    X6        2015  39051.0 km   Diesel  automatique
# 2  80379.0     AUDI   RS6        2014  75381.0 km  Essence  automatique
# 3   2830.0     FORD    KA        2007  92282.0 km  Essence    mécanique
# 4  12925.0     FIAT  TIPO        2018     10.0 km  Essence    mécanique
#
#                Online                                        Description
# 0   06/07/2018 à 3h47  modele: 308 (2E GENERATION), version: 1.6 HDI ...
# 1  03/04/2018 à 16h41  modele: X6 F16, version: (F16) XDRIVE30D 258 M...
# 2   30/07/2018 à 1h55  modele: RS6 (3E GENERATION) AVANT, version: II...
# 3  09/07/2018 à 14h12  modele: KA, version: 1.3 70 FUN, puissance_fis...
# 4   19/05/2018 à 3h52  modele: TIPO 2 SW, version: II SW 1.4 95 POP, ...

# %%
plt.hist(df['Price'], bins=100, range=(df['Price'].min(), df['Price'].max()))
# Out:
# (array([7.5674e+04, 6.9703e+04, 1.3759e+04, 4.0390e+03, 1.6100e+03,
#         7.8800e+02, 3.7200e+02, 2.1000e+02, 1.4700e+02, 1.1800e+02,
#         5.4000e+01, 4.0000e+01, 5.1000e+01, 3.6000e+01, 2.5000e+01,
#         1.3000e+01, 8.0000e+00, 8.0000e+00, 6.0000e+00, 7.0000e+00,
#         7.0000e+00, 2.0000e+00, 1.0000e+00, 1.0000e+00, 3.0000e+00,
#         1.0000e+00, 2.0000e+00, 0.0000e+00, 1.0000e+00, 2.0000e+00,
#         0.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00, 0.0000e+00,
#         1.0000e+00, 1.0000e+00, 0.0000e+00, 1.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 2.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00,
#         0.0000e+00, 0.0000e+00, 0.0000e+00, 0.0000e+00, 1.0000e+00]),
#  array([1.00000000e+00, 1.48659900e+04, 2.97309800e+04, 4.45959700e+04,
#         5.94609600e+04, 7.43259500e+04, 8.91909400e+04, 1.04055930e+05,
#         1.18920920e+05, 1.33785910e+05, 1.48650900e+05, 1.63515890e+05,
#         1.78380880e+05, 1.93245870e+05, 2.08110860e+05, 2.22975850e+05,
#         2.37840840e+05, 2.52705830e+05, 2.67570820e+05, 2.82435810e+05,
#         2.97300800e+05, 3.12165790e+05, 3.27030780e+05, 3.41895770e+05,
#         3.56760760e+05, 3.71625750e+05, 3.86490740e+05, 4.01355730e+05,
#         4.16220720e+05, 4.31085710e+05, 4.45950700e+05, 4.60815690e+05,
#         4.75680680e+05, 4.90545670e+05, 5.05410660e+05, 5.20275650e+05,
#         5.35140640e+05, 5.50005630e+05, 5.64870620e+05, 5.79735610e+05,
#         5.94600600e+05, 6.09465590e+05, 6.24330580e+05, 6.39195570e+05,
#         6.54060560e+05, 6.68925550e+05, 6.83790540e+05, 6.98655530e+05,
#         7.13520520e+05, 7.28385510e+05, 7.43250500e+05, 7.58115490e+05,
#         7.72980480e+05, 7.87845470e+05, 8.02710460e+05, 8.17575450e+05,
#         8.32440440e+05, 8.47305430e+05, 8.62170420e+05, 8.77035410e+05,
#         8.91900400e+05, 9.06765390e+05, 9.21630380e+05, 9.36495370e+05,
#         9.51360360e+05, 9.66225350e+05, 9.81090340e+05, 9.95955330e+05,
#         1.01082032e+06, 1.02568531e+06, 1.04055030e+06, 1.05541529e+06,
#         1.07028028e+06, 1.08514527e+06, 1.10001026e+06, 1.11487525e+06,
#         1.12974024e+06, 1.14460523e+06, 1.15947022e+06, 1.17433521e+06,
#         1.18920020e+06, 1.20406519e+06, 1.21893018e+06, 1.23379517e+06,
#         1.24866016e+06, 1.26352515e+06, 1.27839014e+06, 1.29325513e+06,
#         1.30812012e+06, 1.32298511e+06, 1.33785010e+06, 1.35271509e+06,
#         1.36758008e+06, 1.38244507e+06, 1.39731006e+06, 1.41217505e+06,
#         1.42704004e+06, 1.44190503e+06, 1.45677002e+06, 1.47163501e+06,
#         1.48650000e+06]),
#  <a list of 100 Patch objects>)

# %%
df['Make'].value_counts()
# Out:
# RENAULT           30690
# PEUGEOT           26119
# CITROEN           17609
# VOLKSWAGEN        11241
# BMW                9424
#                   ...
# MPM MOTORS            1
# BELLIER               1
# AUTOBIANCHI           1
# INTERMECCANICA        1
# SIMCA                 1
# Name: Make, Length: 92, dtype: int64

# %%
df['Model'].value_counts().head()
# Out:
# CLIO      7967
# 308       6123
# 208       6053
# MEGANE    5212
# CAPTUR    4410
# Name: Model, dtype: int64

# %%
df['Fuel'].value_counts()
# Out:
# Diesel                              109446
# Essence                              53392
# Hybride essence électrique            2725
# Electrique                             704
# Hybride diesel électrique              310
# Bicarburation essence GPL               96
# Bicarburation essence bioéthanol        21
# Bicarburation essence GNV                1
# Name: Fuel, dtype: int64

# %%
df['Gearbox'].value_counts()
# Out:
# mécanique      113014
# automatique     53681
# Name: Gearbox, dtype: int64

# %%
dict_handwritten = {
        "Price": {
            "type": "numerical",
            "description": "Price of the car",
        },
        "Make": {
            "type": "categorical",
            "description": "Brand of the car"
        },
        "Model": {
            "type": "categorical",
            "description": "Model of the car"
        },
        "Model_year": {
            "type": "date",
            "description": "Year of release of the model"
        },
        "Mileage": {
            "type": "numerical",
            "description": "Distance ride by the car"
        },
        "Fuel": {
            "type": "categorical",
            "description": "Type of fuel"
        },
        "Gearbox": {
            "type": "categorical",
            "description": "Type of gearbox"
        },
        "Online": {
            "type": "date",
            "description": "publishing date of the offer"
        },
        "Description": {
            "type": "text",
            "description": "text written by the user about the offer"
        },
    }

# %%
for item in dict_handwritten.items():
    feature_name = item[0]
    feature_type = item[1]['type']
    feature_description = item[1]['description']
    if feature_type == "numerical":
        max_value = df[feature_name].max()
        min_value = df[feature_name].min()
        dict_handwritten.get(feature_name).update({'max_value': max_value})
        dict_handwritten.get(feature_name).update({'min_value': min_value})
    if feature_type == "categorical":
        unique_value = df[feature_name].unique()
        dict_handwritten.get(feature_name).update({'unique_value': list(unique_value)})

# %%
dict_handwritten
# Out:
# {'Price': {'type': 'numerical',
#   'description': 'Price of the car',
#   'max_value': 1486500.0,
#   'min_value': 1.0},
#  'Make': {'type': 'categorical',
#   'description': 'Brand of the car',
#   'unique_value': ['PEUGEOT',
#    'BMW',
#    'AUDI',
#    'FORD',
#    'FIAT',
#    'RENAULT',
#    'MERCEDES',
#    'SEAT',
#    'MINI',
#    'HYUNDAI',
#    'DACIA',
#    'VOLKSWAGEN',
#    'CITROEN',
#    'TOYOTA',
#    'JAGUAR',
#    'OPEL',
#    'PORSCHE',
#    'NISSAN',
#    'LAND ROVER',
#    'MAZDA',
#    'VOLVO',
#    'SKODA',
#    'DS',
#    'SSANGYONG',
#    'SUZUKI',
#    'HONDA',
#    'LEXUS',
#    'INFINITI',
#    'JEEP',
#    'KIA',
#    'DODGE',
#    'ASTON MARTIN',
#    'LANCIA',
#    'LOTUS',
#    'CHEVROLET',
#    'SMART',
#    'ALFA ROMEO',
#    'BUGATTI',
#    'MITSUBISHI',
#    'MERCEDES-AMG',
#    'AIXAM',
#    'FERRARI',
#    'MG',
#    'LAMBORGHINI',
#    'MASERATI',
#    'SUBARU',
#    'MORGAN',
#    'CHRYSLER',
#    'ROLLS ROYCE',
#    'TESLA',
#    'ABARTH',
#    'LADA',
#    'BMW-ALPINA',
#    'SAAB',
#    'PACKARD',
#    'CADILLAC',
#    'ROVER',
#    'SHELBY',
#    'MICROCAR',
#    'ALPINA',
#    'BENTLEY',
#    'DAIHATSU',
#    'HUMMER',
#    'TRIUMPH',
#    'LIGIER',
#    'DAEWOO',
#    'AUSTIN HEALEY',
#    'JIAYUAN',
#    'MCLAREN',
#    'AUSTIN',
#    'DANGEL',
#    'CATERHAM',
#    'CHATENET',
#    'INTERMECCANICA',
#    'AC',
#    'AUTOBIANCHI',
#    'SUNBEAM',
#    'MIA ELECTRIC',
#    'BOLLORE',
#    'MPM MOTORS',
#    'INNOCENTI',
#    'MATRA',
#    'DONKERVOORT',
#    'GRECAV',
#    'BURBY S',
#    'FISKER',
#    'ALPINE',
#    'SIMCA',
#    'OLDSMOBILE',
#    'BELLIER',
#    'SECMA',
#    'RILEY']},
#  'Model': {'type': 'categorical',
#   'description': 'Model of the car',
#   'unique_value': ['308',
#    'X6',
#    'RS6',
#    'KA',
#    'TIPO',
#    'X3',
#    'A3',
#    'MEGANE',
#    'C-MAX',
#    'CLASSE C',
#    'IBIZA',
#    'MINI',
#    '500 X',
#    'MONDEO',
#    'I20',
#    'SANDERO',
#    '208',
#    'GOLF',
#    'C3',
#    'AURIS',
#    'I30',
#    'POLO',
#    'SERIE 1',
#    'XKR',
#    'CLASSE B',
#    'CLIO',
#    'TOURAN',
#    'CLASSE R',
#    'TIGUAN',
#    'TALISMAN',
#    'ASTRA',
#    'GRAND SCENIC',
#    'A4',
#    'DS3',
#    '407',
#    'DUSTER',
#    'MACAN',
#    'QASHQAI',
#    'KADJAR',
#    'SCENIC',
#    'A5',
#    'TWINGO',
#    'PASSAT',
#    'ARONA',
#    'GRAND C-MAX',
#    'KUGA',
#    'SERIE 2',
#    'SL',
#    '500',
#    'C4',
#    '5008',
#    '3008',
#    'GRAND C4 SPACETOURER',
#    'KOLEOS',
#    'CLASSE A',
#    'C4 PICASSO',
#    '2008',
#    'SERIE 5',
#    'C5',
#    'SERIE 3 GT',
#    'C3 AIRCROSS',
#    'LEON',
#    'TUCSON',
#    'RANGE ROVER EVOQUE',
#    'ESPACE',
#    'A7',
#    'SERIE 3',
#    'ZAFIRA',
#    '6',
#    'XC60',
#    '1007',
#    'AVENSIS',
#    'OCTAVIA',
#    'YARIS',
#    'JUKE',
#    '508 RXH',
#    'V40',
#    '108',
#    '508',
#    'SERIE 4',
#    'DS 5',
#    'CAPTUR',
#    'GLA',
#    '307',
#    'TRAVELLER',
#    'CORSA',
#    'COCCINELLE',
#    'RAV 4',
#    'KYRON',
#    'X5',
#    'MULTIPLA',
#    'S-MAX',
#    'SX4',
#    'MOKKA X',
#    'X1',
#    'LAGUNA',
#    'PARTNER TEPEE',
#    'C4 CACTUS',
#    'SUPERB',
#    'CLASSE E',
#    'A6 ALLROAD',
#    'CLA',
#    'Q2',
#    'ADAM',
#    'A1',
#    '206',
#    '807',
#    'YETI',
#    'Q3',
#    'MX5',
#    'GRAND C4 PICASSO',
#    'Q5',
#    'IX35',
#    '911',
#    'LAND CRUISER SW',
#    'GRAND KANGOO',
#    'KANGOO',
#    'JAZZ',
#    'IS',
#    'DOKKER',
#    'FOCUS',
#    'NX',
#    'XJ',
#    'Q30',
#    '3',
#    'CLASSE S',
#    'VERSO',
#    'RENEGADE',
#    'ZOE',
#    'MOKKA',
#    'FABIA',
#    'SPORTAGE',
#    'MUSTANG',
#    'CLASSE CLS',
#    'FIESTA',
#    'DS4',
#    'CIVIC',
#    'MINI CABRIOLET',
#    '207',
#    'ECOSPORT',
#    'LS',
#    'CLASSE M',
#    'C3 PICASSO',
#    'C1',
#    'NOTE',
#    'V90 CROSS COUNTRY',
#    'A4 ALLROAD',
#    'SERIE 6',
#    'X-TRAIL',
#    'RCZ',
#    'CHALLENGER',
#    'RAPIDE',
#    'VITARA',
#    'SAXO',
#    'PANDA',
#    'DS 3',
#    'MERIVA',
#    'IX20',
#    'GRAND CHEROKEE',
#    'MICRA',
#    'RS4',
#    'DS 4',
#    'YPSILON',
#    'COUNTRYMAN',
#    'CAYENNE',
#    'RIO',
#    'FREEMONT',
#    'ATECA',
#    'V50',
#    'B-MAX',
#    'ION',
#    'ELISE',
#    'SORENTO',
#    'C4 AIRCROSS',
#    'MATIZ',
#    'FORTWO',
#    'GRANDLAND X',
#    'V40 CROSS COUNTRY',
#    'BERLINGO',
#    'PUNTO',
#    'DISCOVERY SPORT',
#    'GLC',
#    'DOBLO',
#    'GIULIETTA',
#    'R8',
#    'PARTNER',
#    'C30',
#    'V60',
#    'VEYRON',
#    'MODUS',
#    'XC90',
#    '1200',
#    'COUGAR',
#    'RANGE ROVER SPORT',
#    'DEFENDER',
#    'COMPASS',
#    '718',
#    'PASSAT CC',
#    'TOUAREG',
#    'LOGAN',
#    'XF',
#    'KA+',
#    'QASHQAI +2',
#    '500 L',
#    'C2',
#    'OUTLANDER',
#    'AGILA',
#    'C-HR',
#    'TOURNEO COURIER',
#    'DISCOVERY',
#    'OPTIMA',
#    'BOXSTER',
#    'CHEROKEE',
#    'EDGE',
#    'AYGO',
#    'GRAND MODUS',
#    'DS5',
#    'CLASSE V',
#    'T-ROC',
#    'KARL',
#    'IGNIS',
#    'PANAMERA',
#    'GRANDE PUNTO',
#    'I10',
#    'CX-3',
#    'C-ZERO',
#    'F-PACE',
#    'S60',
#    'VIANO',
#    'WIND',
#    'PRIUS',
#    'LAND CRUISER',
#    'CX-7',
#    'TT',
#    '607',
#    '370Z',
#    'FREELANDER',
#    'CARENS',
#    'GT',
#    'ALHAMBRA',
#    'FORFOUR',
#    'SWIFT',
#    'GIULIA',
#    'PAJERO',
#    'E-PACE',
#    'STELVIO',
#    'UP!',
#    'KODIAQ',
#    'ZAFIRA TOURER',
#    'GALLOPER',
#    'PACEMAN',
#    'CLASSE G',
#    'BIPPER TEPEE',
#    'COLT',
#    '4008',
#    'INSIGNIA',
#    'I40',
#    'GLS',
#    'COUPE',
#    '107',
#    'A6',
#    'CR-V',
#    'C-ELYSEE',
#    'ASX',
#    'SMART',
#    '488',
#    'DS 4 CROSSBACK',
#    'C25',
#    'XC70',
#    'TIGUAN ALLSPACE',
#    'SPLASH',
#    'CRUZE',
#    'CEE D',
#    'PULSAR',
#    'SUBURBAN',
#    'V70',
#    'RX',
#    'UNO',
#    'A',
#    'Q7',
#    'TRAX',
#    'GALLARDO',
#    'QUATTROPORTE',
#    'C8',
#    'SANTA FE',
#    'X4',
#    'FX',
#    'SPACE STAR',
#    'FORESTER',
#    'TTS',
#    'SPACETOURER',
#    'C',
#    'SQ5',
#    'AERO 8',
#    'QX30',
#    'SHARAN',
#    'CAMARO',
#    'VENGA',
#    'GOLF SPORTSVAN',
#    'CX-5',
#    'ALTO',
#    'RS5',
#    'V90',
#    'CROSSLAND X',
#    'LODGY',
#    'SLK',
#    'GALAXY',
#    'GRAND TOURNEO CONNECT',
#    'PT CRUISER',
#    'EXEO',
#    'XE',
#    'CROSSFIRE',
#    'I3',
#    'PHANTOM',
#    'URBAN CRUISER',
#    '206+',
#    'SX4 S-CROSS',
#    'S40',
#    'STONIC',
#    'PICASSO',
#    'DELTA',
#    'HR-V',
#    'ACCORD',
#    'RANGE ROVER',
#    'FUSION',
#    'VIRAGE',
#    '612',
#    'RANGE ROVER VELAR',
#    'CADDY',
#    'V8 VANTAGE',
#    'TWIZY',
#    'SM',
#    'LEVANTE',
#    'E-MEHARI',
#    'GRANCABRIO',
#    'CORVETTE',
#    'MODEL X',
#    '300',
#    'TERRANO',
#    'IQ',
#    'GLE',
#    'GT-R',
#    'NIVA',
#    'KONA',
#    'B3 S',
#    'X2',
#    'SERIE 7',
#    'COROLLA',
#    'LATITUDE',
#    'S3',
#    '147',
#    '160',
#    'ARTEON',
#    'KORANDO',
#    'PATROL',
#    'ROADSTER',
#    'NEW BEETLE',
#    'PRO CEE D',
#    '2',
#    'MINI CLUBMAN',
#    'NEMO',
#    'COROLLA VERSO',
#    'CLASSE GLK',
#    'GLE COUPE',
#    '9-3',
#    'CELERIO',
#    'PICANTO',
#    'IDEA',
#    'VECTRA',
#    'INSIGHT',
#    'FOCUS C-MAX',
#    'EOS',
#    'EXPERT TEPEE',
#    'F355',
#    'LIANA',
#    'MITO',
#    'JIMNY',
#    'NIRO',
#    'CITIGO',
#    'GRAND VOYAGER',
#    'CLK',
#    'XV',
#    'SOUL',
#    '5',
#    'MK II',
#    'GRAND ESPACE',
#    '2CV',
#    'WRANGLER',
#    'RAPID',
#    'V60 CROSS COUNTRY',
#    'SLC',
#    'CAYMAN',
#    'C3 PLURIEL',
#    'MINI COUPE',
#    'F-TYPE',
#    'GRAND VITARA',
#    'FIORINO',
#    'XK8',
#    '106',
#    'ALTEA',
#    'MODEL S',
#    'XK',
#    '200',
#    'WRAITH',
#    'CC',
#    'GS',
#    'ORLANDO',
#    'SCIROCCO',
#    'F430',
#    'LEAF',
#    'KAROQ',
#    'ALTEA FREETRACK',
#    'S90',
#    'CROMA',
#    'Q50',
#    'FF',
#    'KALOS',
#    'CALIBER',
#    '4/4',
#    'IONIQ',
#    'GOLF PLUS',
#    'CT',
#    'CARNIVAL',
#    'CALIFORNIA',
#    'Z4',
#    'GRANTURISMO',
#    'MATRIX',
#    '458',
#    'TYPE E',
#    'TOLEDO',
#    'ANTARA',
#    'MII',
#    'S-TYPE',
#    'LANCER',
#    'DB11',
#    'IMPREZA',
#    'FR-V',
#    'GT86',
#    'WILLYS',
#    'CL',
#    'RC',
#    'CLIPPER',
#    'RS Q3',
#    'XSARA',
#    'X-TYPE',
#    'RS3',
#    'GETZ',
#    'S5',
#    'PUNTO EVO',
#    'S80',
#    'ALLROAD',
#    'VANQUISH',
#    '124',
#    'ESCALADE',
#    'SERIE 5 GT',
#    'A8',
#    '207+',
#    'GLC COUPE',
#    'TAHOE',
#    '159',
#    'GT 500',
#    'SPARK',
#    'TERRACAN',
#    'TRANSIT CUSTOM',
#    'M.GO',
#    'XD3',
#    'PIXO',
#    'PROACE VERSO',
#    'PRIMERA',
#    'ROOMSTER',
#    '300 C',
#    'ECLIPSE CROSS',
#    '3.0',
#    'OUTBACK',
#    'CROSSOVER',
#    'CONTINENTAL',
#    'PROACE',
#    'LACETTI',
#    'DBS',
#    'P4',
#    'SIERRA',
#    '944',
#    'TREVIS',
#    'TT RS',
#    'MUSA',
#    'I8',
#    'JETTA',
#    'CUSTOM',
#    'FOX',
#    'C6',
#    '146',
#    'EVALIA',
#    '406',
#    'H3',
#    'NP300 NAVARA',
#    'VERSO-S',
#    'XC40',
#    'ATS',
#    'ZX',
#    'VEL SATIS',
#    '306',
#    'FLAVIA',
#    'H1',
#    'DB9',
#    'FLUENCE',
#    'S8',
#    'GHIBLI',
#    '356',
#    'LEVORG',
#    'X1/9',
#    'ULYSSE',
#    'AMI',
#    'CAPTIVA',
#    '404',
#    'TOURNEO CONNECT',
#    'VOYAGER',
#    'C-CROSSER',
#    'AVEO',
#    'BARCHETTA',
#    'BALENO',
#    'CR-Z',
#    'VELOSTER',
#    'REXTON',
#    'S4',
#    'SAMURAI',
#    '205',
#    'SLS',
#    'FLYING SPUR',
#    'ALFETTA',
#    'HURACAN',
#    'IX55',
#    'CITY',
#    'XT5',
#    'DUE',
#    'Z3',
#    'EXIGE',
#    'NITRO',
#    'MALIBU',
#    'F12',
#    'THUNDERBIRD',
#    'Q60',
#    'STINGER',
#    'CASCADA',
#    'C70',
#    '33',
#    'DAWN',
#    '4007',
#    'MULTIVAN',
#    'BRERA',
#    'JUMPY',
#    'TR 6',
#    'P1800',
#    'QX70',
#    'PRIUS+',
#    'QUBO',
#    'REZZO',
#    'SUNNY',
#    'BRZ',
#    '4C',
#    'AVANTIME',
#    'CORDOBA',
#    'SUPER 5',
#    'DS 7 CROSSBACK',
#    'CLASSE GL',
#    '504',
#    'XANTIA',
#    '350Z',
#    'PHAETON',
#    'JS',
#    '599',
#    'MUSSO',
#    'SHUMA',
#    '812 SUPERFAST',
#    'SC',
#    'S6',
#    'SPRITE',
#    'SATELLITE',
#    'SQ7',
#    'MURCIELAGO',
#    'F150',
#    'ROADSTER V6',
#    '99',
#    'S1',
#    '121',
#    'CITY FUN',
#    'CTS',
#    '190',
#    'Q70',
#    'STILO',
#    'COMBO',
#    '9-5',
#    'FRONTERA',
#    'R4',
#    'ATOS',
#    'MP4-12C',
#    'AVENTADOR',
#    '420',
#    'CLASSE CLC',
#    'JUSTY',
#    'CARAVELLE',
#    '330',
#    '3000',
#    'A2',
#    'BRAVA',
#    'ATOS PRIME',
#    'SILVER SHADOW',
#    'SIRION',
#    'PHEDRA',
#    'THESIS',
#    'SPIDER',
#    'MINI ROADSTER',
#    'QX50',
#    'RS7',
#    'MINAUTO',
#    'VANEO',
#    'TOURNEO',
#    'LUPO',
#    'DURANGO',
#    'BRAVO',
#    'VOLT',
#    'SIGNUM',
#    'GTC4LUSSO',
#    'GMC',
#    'BENTAYGA',
#    'TR 7',
#    'CJ6',
#    '812',
#    '626',
#    'TR 3',
#    'SEICENTO',
#    'SPYDER',
#    'MURANO',
#    'WRX STI',
#    'TIVOLI',
#    'SUPER SEVEN',
#    'R5',
#    'LC',
#    'ACCENT',
#    'OLYMPIA',
#    'TIGRA',
#    'ALMERA TINO',
#    'MEHARI',
#    'CH 40',
#    'GRAND SANTA FE',
#    'WAGON R+',
#    'XJS',
#    'ELAN',
#    'THEMA',
#    'JOURNEY',
#    '604',
#    'GRANSPORT',
#    'VIPER',
#    '400',
#    'EVORA',
#    '309',
#    'PATHFINDER',
#    'MONDIAL',
#    'MAGENTIS',
#    'DS',
#    'SPEEDSTER',
#    'XJ8',
#    '456',
#    '45',
#    'SONATA',
#    'COBRA',
#    'TERIOS',
#    'A112',
#    'SPITFIRE',
#    'C15',
#    '280',
#    'RODEO',
#    '25',
#    'CONCERTO',
#    'GTV',
#    'KALINA',
#    '720S',
#    'GRAND VITARA XL-7',
#    'ALPINE',
#    'ASCONA',
#    'TF',
#    'BETA',
#    'C10',
#    '570S',
#    'F',
#    'T',
#    '348',
#    '75',
#    'G',
#    'COPEN',
#    'XLR',
#    'TESTAROSSA',
#    '230',
#    'AROSA',
#    '575',
#    'TIVOLI XLV',
#    'MIA',
#    'CT6',
#    'HHR',
#    '512',
#    'BLUECAR',
#    'DB7',
#    'H2',
#    'D3',
#    'DAIMLER',
#    'BUGGY',
#    '650 S',
#    '170',
#    'FORD',
#    '156',
#    'SEDICI',
#    'COMMANDER',
#    'A721',
#    'SEVILLE',
#    '80',
#    'SAFRANE',
#    'MULSANNE',
#    'ACTYON',
#    'SRX',
#    'C4 SPACETOURER',
#    '360',
#    'PROWLER',
#    'THREEWHEELER',
#    '1000',
#    'BLUESUMMER',
#    'OMEGA',
#    'PATRIOT',
#    'PUMA',
#    'ELDORADO',
#    '928',
#    '806',
#    'MINI-MOKE',
#    'ESPRIT',
#    'LEGACY',
#    'PS.160',
#    'CORNICHE',
#    '250',
#    'BORA',
#    'SERIE 200',
#    'STRATUS',
#    '180',
#    'TR 4',
#    '365',
#    'FULVIA',
#    'TRAJET',
#    '75 LIMOUSINE BVA',
#    'AVENGER',
#    'RODIUS',
#    'EX',
#    'MAREA',
#    'GHOST',
#    'YARIS VERSO',
#    '550',
#    'SEBRING',
#    'JET',
#    'CITAN',
#    '450',
#    'ESCORT',
#    'S7',
#    'NOVA',
#    'I-MIEV',
#    'AVENSIS VERSO',
#    '2002',
#    'TR 5',
#    '1300',
#    'AMAROK',
#    'TREZIA',
#    'PREMACY',
#    '126',
#    'TRACTION',
#    'XJ12',
#    '505',
#    '560',
#    'LEBARON',
#    'STREAM',
#    '130',
#    'EPICA',
#    'EXPLORER',
#    'PALIO',
#    'ALMERA',
#    'X-TOO',
#    'KANGOO EXPRESS',
#    'GRANDIS',
#    'AX',
#    'STAG',
#    'MATERIA',
#    'DINO',
#    'CROSSBLADE',
#    'PLUS 4',
#    'D8',
#    '675 LT',
#    'DB4',
#    'CH 26',
#    'XM',
#    'VANTAGE',
#    'CABSTAR',
#    'MAVERICK',
#    '403',
#    'CX',
#    'EVASION',
#    'CTS-V',
#    'SHUTTLE',
#    'K5 BLAZER',
#    'EKE',
#    'CROSSLINE',
#    'E-MOKE',
#    'GENESIS',
#    '2600',
#    '145',
#    'KARMA',
#    'B',
#    '924',
#    'X-TOO MAX',
#    'GTA',
#    'STS',
#    '3200 GT',
#    'TRAILBLAZER',
#    'CHEVELLE',
#    'NV200',
#    'CUTLASS',
#    'M',
#    '166',
#    'B8',
#    'F-16',
#    'XJ6',
#    'CERATO',
#    'TORONADO',
#    'S2',
#    'A610',
#    'ARNAGE',
#    'MINI MOKE',
#    'IMPALA',
#    'PLUS 8',
#    'SEVEN',
#    'CUBE',
#    'CX-9',
#    'DYANE',
#    'ELF',
#    'PREVIA',
#    'LAND',
#    'DUETTO',
#    'SILVERADO',
#    'EL CAMINO',
#    '2 ELEVEN',
#    'TC',
#    'CHARGER',
#    'BX']},
#  'Model_year': {'type': 'date', 'description': 'Year of release of the model'},
#  'Mileage': {'type': 'numerical',
#   'description': 'Distance ride by the car',
#   'max_value': '99999.0 km',
#   'min_value': '1.0 km'},
#  'Fuel': {'type': 'categorical',
#   'description': 'Type of fuel',
#   'unique_value': ['Diesel',
#    'Essence',
#    'Hybride essence électrique',
#    'Electrique',
#    'Bicarburation essence GNV',
#    'Hybride diesel électrique',
#    'Bicarburation essence GPL',
#    'Bicarburation essence bioéthanol']},
#  'Gearbox': {'type': 'categorical',
#   'description': 'Type of gearbox',
#   'unique_value': ['mécanique', 'automatique']},
#  'Online': {'type': 'date', 'description': 'publishing date of the offer'},
#  'Description': {'type': 'text',
#   'description': 'text written by the user about the offer'}}

# %%
df['descrip_modele'] =  df['Description'].str.extract('(modele:.*(?=, version))')
df['descrip_modele'] = df['descrip_modele'].str.replace('modele: ', '')

df['descrip_version'] = df['Description'].str.extract('(version:.*(?=, puissance_fiscale))')
df['descrip_version'] = df['descrip_version'].str.replace('version: ', '')
#df['descrip_version'] = df['descrip_version'].replace(df['Model'], '', regex=True)

df['descrip_puiss_fiscale'] = df['Description'].str.extract('(puissance_fiscale:.*(?=, portes:))')
df['descrip_puiss_fiscale'] = df['descrip_puiss_fiscale'].str.replace('puissance_fiscale: ', '')
df['descrip_puiss_fiscale'] = df['descrip_puiss_fiscale'].astype('int32')

df['descrip_portes'] = df['Description'].str.extract('(portes:.*(?=, options))')
df['descrip_portes'] = df['descrip_portes'].str.replace('portes: ', '')
df['descrip_portes'] = df['descrip_portes'].str.split('.', expand=True)[0].astype('int32', errors='ignore')
# Todo Handle missing value

df['descrip_options'] =  df['Description'].str.extract('(options:.*(?=, couleur))')
df['descrip_options'] = df['descrip_options'].str.replace('options: ', '')

df['descrip_couleur'] = df['Description'].str.extract('(couleur:.*)')
df['descrip_couleur'] = df['descrip_couleur'].str.replace('couleur: ', '')

# %%
df['Description'][4]
# Out:
# "modele: TIPO 2 SW, version: II SW 1.4 95 POP, puissance_fiscale: 5, portes: 5.0, options: Volant alu & cuir;Bluetooth inclut musique en streaming, connexion téléphone;Rétroviseurs extérieurs chauffants;Roue de secours de taille normale;Antibrouillards avant;Taille écran multi-fonctions 5 pouces;Antipatinage;Indicateur de sous-gonflage des pneus;Ouverture du coffre à distance;6 airbags;6 haut-parleurs;Air conditionné manuel;Rétroviseurs extérieurs réglage électrique;Réglage du volant en hauteur, en profondeur;ESP;Airbags rideaux;Airbags latéraux;Aide au démarrage en côte;Ordinateur de bord;ABS;Volant multi-fonction;Assistance au freinage d'urgence;Bluetooth;Ampoules de phares halogènes, couleur: blanc verni"

# %%
df['descrip_modele'][4]
# Out:
# 'TIPO 2 SW'

# %%
df['descrip_options'][4]
# Out:
# "Volant alu & cuir;Bluetooth inclut musique en streaming, connexion téléphone;Rétroviseurs extérieurs chauffants;Roue de secours de taille normale;Antibrouillards avant;Taille écran multi-fonctions 5 pouces;Antipatinage;Indicateur de sous-gonflage des pneus;Ouverture du coffre à distance;6 airbags;6 haut-parleurs;Air conditionné manuel;Rétroviseurs extérieurs réglage électrique;Réglage du volant en hauteur, en profondeur;ESP;Airbags rideaux;Airbags latéraux;Aide au démarrage en côte;Ordinateur de bord;ABS;Volant multi-fonction;Assistance au freinage d'urgence;Bluetooth;Ampoules de phares halogènes"

# %%
df['descrip_options'][0]
# Out:
# "banquette arrière 3 places;volant cuir;cache bagages;airbag frontal;banquette 1/3 - 2/3;sièges rang 2 rabattables à plat;vitres teintées;boucliers av et ar couleur caisse;phares av. de jour à LED;airbags rideaux;rétroviseurs électriques et dégivrants;siège conducteur avec réglage lombaire;vitres électriques;feux de freinage d'urgence;banquette rabattable;feux ar. à LED;AFU;contrôle de pression des pneus;airbags front. + lat.;blanc banquise;lampes de lecture à l'arrière;sièges réglables en hauteur;alarme d'oubli d'extinction des feux;EBD;volant sport;température extérieure;système audio;becquet;feux automatiques;fermeture électrique;ESP;fermeture électrique automatique;bacs de portes avant;anti patinage;accoudoir central avant;commandes du système audio au volant;fixations ISOFIX;poches d'aumonières;lampes de lecture à l'avant;lunette arrière dégivrante;essuie-glace arrière;ordinateur de bord;phares halogènes;climatisation;volant réglable en hauteur et profondeur;siège conducteur réglable hauteur;boite à gants réfrigérée;ABS;ceintures avant ajustables en hauteur;prise 12V;ecran tactile multifonction;FAP;3 ceintures ar. 3 points;ouverture des vitres séquentielle"

# %%
df.head(30)
# Out:
#       Price        Make     Model  Model_year      Mileage  \
# 0   11220.0     PEUGEOT       308        2014   94341.0 km
# 1   57526.0         BMW        X6        2015   39051.0 km
# 2   80379.0        AUDI       RS6        2014   75381.0 km
# 3    2830.0        FORD        KA        2007   92282.0 km
# 4   12925.0        FIAT      TIPO        2018      10.0 km
# 5   27956.0         BMW        X3        2012   95623.0 km
# 6   16888.0        AUDI        A3        2013   49018.0 km
# 7   18188.0     RENAULT    MEGANE        2017    9795.0 km
# 8   10594.0        FORD     C-MAX        2012  126670.0 km
# 9   69131.0    MERCEDES  CLASSE C        2015   39439.0 km
# 10  14158.0        SEAT     IBIZA        2017   12464.0 km
# 11  18824.0        MINI      MINI        2015   25662.0 km
# 12  18683.0        FIAT     500 X        2017   25693.0 km
# 13   2945.0        FORD    MONDEO        2004  113417.0 km
# 14   6934.0     HYUNDAI       I20        2012   38494.0 km
# 15  11906.0       DACIA   SANDERO        2017      50.0 km
# 16  14384.0     PEUGEOT       208        2018      10.0 km
# 17   6432.0  VOLKSWAGEN      GOLF        2010  229377.0 km
# 18   6824.0     CITROEN        C3        2014  111206.0 km
# 19  20675.0      TOYOTA     AURIS        2017   25282.0 km
# 20  21439.0     HYUNDAI       I30        2017     987.0 km
# 21  13934.0  VOLKSWAGEN      POLO        2017   10319.0 km
# 22  25407.0     RENAULT    MEGANE        2018      20.0 km
# 23  32472.0         BMW   SERIE 1        2017      10.0 km
# 24  34948.0      JAGUAR       XKR        2007   74235.0 km
# 25  23750.0    MERCEDES  CLASSE B        2016   19970.0 km
# 26  12887.0     PEUGEOT       208        2016   13039.0 km
# 27  24466.0         BMW   SERIE 1        2016   20082.0 km
# 28  12925.0     RENAULT      CLIO        2016    9231.0 km
# 29  18746.0  VOLKSWAGEN    TOURAN        2017   22623.0 km
#
#                           Fuel      Gearbox              Online  \
# 0                       Diesel    mécanique   06/07/2018 à 3h47
# 1                       Diesel  automatique  03/04/2018 à 16h41
# 2                      Essence  automatique   30/07/2018 à 1h55
# 3                      Essence    mécanique  09/07/2018 à 14h12
# 4                      Essence    mécanique   19/05/2018 à 3h52
# 5                       Diesel  automatique   14/03/2018 à 4h24
# 6                       Diesel    mécanique  16/04/2018 à 21h35
# 7                       Diesel  automatique  29/04/2018 à 12h44
# 8                       Diesel    mécanique   22/06/2018 à 5h11
# 9                      Essence  automatique  08/03/2018 à 17h35
# 10                      Diesel    mécanique   25/02/2018 à 1h15
# 11                      Diesel  automatique   02/06/2018 à 5h31
# 12                     Essence  automatique   14/03/2018 à 7h49
# 13                     Essence    mécanique  02/05/2018 à 10h17
# 14                      Diesel    mécanique  01/07/2018 à 15h43
# 15                     Essence    mécanique   15/05/2018 à 8h10
# 16                     Essence    mécanique   12/05/2018 à 6h19
# 17                      Diesel  automatique  02/07/2018 à 14h29
# 18                      Diesel    mécanique  05/09/2018 à 20h56
# 19  Hybride essence électrique  automatique   31/03/2018 à 7h57
# 20                      Diesel    mécanique  02/10/2018 à 17h52
# 21                     Essence    mécanique   05/04/2018 à 1h18
# 22                     Essence  automatique  26/08/2018 à 21h30
# 23                      Diesel  automatique  22/06/2018 à 14h41
# 24                     Essence  automatique   05/09/2018 à 1h11
# 25                      Diesel  automatique  12/06/2018 à 14h45
# 26                      Diesel    mécanique   16/07/2018 à 9h13
# 27                      Diesel    mécanique  18/07/2018 à 20h38
# 28                      Diesel    mécanique   10/05/2018 à 7h29
# 29                      Diesel    mécanique  30/07/2018 à 12h31
#
#                                           Description  \
# 0   modele: 308 (2E GENERATION), version: 1.6 HDI ...
# 1   modele: X6 F16, version: (F16) XDRIVE30D 258 M...
# 2   modele: RS6 (3E GENERATION) AVANT, version: II...
# 3   modele: KA, version: 1.3 70 FUN, puissance_fis...
# 4   modele: TIPO 2 SW, version: II SW 1.4 95 POP, ...
# 5   modele: X3 F25, version: (F25) XDRIVE35D 313 S...
# 6   modele: A3 (2E GENERATION) SPORTBACK, version:...
# 7   modele: MEGANE 4 ESTATE, version: IV ESTATE 1....
# 8   modele: C-MAX 2, version: II 1.6 TDCI 115 FAP ...
# 9   modele: CLASSE C 4 AMG, version: (W205) 63 AMG...
# 10  modele: IBIZA 4, version: IV (2) 1.4 TDI 90 CO...
# 11  modele: MINI 3 5P, version: III 1.5 COOPER D 1...
# 12  modele: 500 X, version: 1.4 MULTIAIR 140 LOUNG...
# 13  modele: MONDEO, version: (2) 1.8 125 GHIA 5P, ...
# 14  modele: I20, version: (2) 1.1 CRDI 75 PACK INV...
# 15  modele: SANDERO 2 STEPWAY, version: II (2) STE...
# 16  modele: 208, version: (2) 1.2 PURETECH 82 ALLU...
# 17  modele: GOLF 6, version: VI 2.0 TDI 110 FAP BL...
# 18  modele: C3 (2E GENERATION), version: II (2) 1....
# 19  modele: AURIS 2 TOURING SPORTS, version: HSD 1...
# 20  modele: I30 (3E GENERATION) SW, version: III S...
# 21  modele: POLO 5, version: V (2) 1.0 75 MATCH 5P...
# 22  modele: , version: 1.6 TCE 205 EDC GT BOSE TPA...
# 23  modele: SERIE 1 F20 5 PORTES, version: (F20) (...
# 24  modele: XKR CABRIOLET, version: CABRIOLET 4.2 ...
# 25  modele: CLASSE B 2, version: II (2) 180 D SENS...
# 26  modele: 208, version: (2) 1.6 BLUEHDI 75 ACTIV...
# 27  modele: SERIE 1 F20 5 PORTES, version: (F20) (...
# 28  modele: CLIO 4, version: IV 1.5 DCI 90 INTENS ...
# 29  modele: TOURAN 3, version: 1.6 TDI 115 EDITION...
#
#                   descrip_modele  \
# 0            308 (2E GENERATION)
# 1                         X6 F16
# 2      RS6 (3E GENERATION) AVANT
# 3                             KA
# 4                      TIPO 2 SW
# 5                         X3 F25
# 6   A3 (2E GENERATION) SPORTBACK
# 7                MEGANE 4 ESTATE
# 8                        C-MAX 2
# 9                 CLASSE C 4 AMG
# 10                       IBIZA 4
# 11                     MINI 3 5P
# 12                         500 X
# 13                        MONDEO
# 14                           I20
# 15             SANDERO 2 STEPWAY
# 16                           208
# 17                        GOLF 6
# 18            C3 (2E GENERATION)
# 19        AURIS 2 TOURING SPORTS
# 20        I30 (3E GENERATION) SW
# 21                        POLO 5
# 22
# 23          SERIE 1 F20 5 PORTES
# 24                 XKR CABRIOLET
# 25                    CLASSE B 2
# 26                           208
# 27          SERIE 1 F20 5 PORTES
# 28                        CLIO 4
# 29                      TOURAN 3
#
#                                       descrip_version  descrip_puiss_fiscale  \
# 0                        1.6 HDI FAP 92CH BUSINESS 5P                      4
# 1                    (F16) XDRIVE30D 258 M SPORT BVA8                     16
# 2            III AVANT 4.0 TFSI 560 QUATTRO TIPTRONIC                     47
# 3                                          1.3 70 FUN                      5
# 4                                    II SW 1.4 95 POP                      5
# 5               (F25) XDRIVE35D 313 SPORT DESIGN BVA8                     20
# 6   II (2) SPORTBACK 2.0 TDI 140 7CV AMBITION LUXE...                      7
# 7                IV ESTATE 1.5 DCI 110 ENERGY ZEN EDC                      5
# 8                   II 1.6 TDCI 115 FAP TITANIUM BVM6                      6
# 9                  (W205) 63 AMG S SPEEDSHIFT MCT AMG                     40
# 10                          IV (2) 1.4 TDI 90 CONNECT                      5
# 11             III 1.5 COOPER D 116 PACK CHILI BVA 5P                      5
# 12                    1.4 MULTIAIR 140 LOUNGE 4X2 DCT                      7
# 13                                (2) 1.8 125 GHIA 5P                      8
# 14                     (2) 1.1 CRDI 75 PACK INVENTIVE                      4
# 15                              II (2) STEPWAY TCE 90                      5
# 16                      (2) 1.2 PURETECH 82 ALLURE 5P                      4
# 17  VI 2.0 TDI 110 FAP BLUEMOTION TECHNOLOGY CARAT...                      5
# 18                     II (2) 1.4 HDI 70 FAP BUSINESS                      4
# 19                                    HSD 136H DESIGN                      5
# 20                       III SW 1.6 CRDI 110 BUSINESS                      5
# 21                              V (2) 1.0 75 MATCH 5P                      4
# 22                      1.6 TCE 205 EDC GT BOSE TPANO                     11
# 23                            (F20) (2) 116DA M SPORT                      6
# 24                  CABRIOLET 4.2 V8 SURALIMENTE BVA6                     32
# 25                      II (2) 180 D SENSATION 7G-DCT                      5
# 26                       (2) 1.6 BLUEHDI 75 ACTIVE 5P                      4
# 27                        (F20) (2) 118D URBANCHIC 5P                      7
# 28                          IV 1.5 DCI 90 INTENS ECO2                      4
# 29                           1.6 TDI 115 EDITION  7PL                      6
#
#    descrip_portes                                    descrip_options  \
# 0               5  banquette arrière 3 places;volant cuir;cache b...
# 1               5  triangle de presignalisation et trousse de pre...
# 2               5  banquette arrière 3 places;écran tactile;témoi...
# 3               3  direction assistée;jantes alu;rétroviseurs éle...
# 4               5  Volant alu & cuir;Bluetooth inclut musique en ...
# 5               5  vitrage calorifuge;triangle de presignalisatio...
# 6               5  "anti démarrage;radar de recul;prises audio au...
# 7               5  régulateur limiteur de vitesse;carte main libr...
# 8               5
# 9               4  régulateur limiteur de vitesse;affichage tête ...
# 10              5  banquette arrière 3 places;écran tactile;blanc...
# 11              5  radar de recul;prises audio auxiliaires;direct...
# 12              5  écran tactile;palettes au volant;volant cuir;r...
# 13              5  "anti démarrage;direction assistée;airbags;rég...
# 14              5  banquette arrière 3 places;prises audio auxili...
# 15              5  écran tactile;régulateur limiteur de vitesse;d...
# 16              5  volant cuir;régulateur limiteur de vitesse;rou...
# 17              5  anti démarrage;régulateur limiteur de vitesse;...
# 18              5  airbags latéraux;rétroviseurs électriques;GPS;...
# 19              5  banquette arrière 3 places;écran tactile;témoi...
# 20              5  écran tactile;prise 220v;volant cuir;régulateu...
# 21              5  information trafic tmc+ via michelin;régulateu...
# 22              5  version 1.6 tce 205 edc gt bose tpano;régulate...
# 23              5  appuie-tete arriere rabattables;volant cuir;di...
# 24              2  radar de recul;GPS;régulateur de vitesse;proje...
# 25              5  banquette arrière 3 places;volant cuir;régulat...
# 26              5  banquette arrière 3 places;régulateur limiteur...
# 27              5  omission du badge exterieur;volant cuir;direct...
# 28              5  écran tactile;joncs de vitres chromés;volant c...
# 29              5  direction assistée;rétroviseurs électriques;GP...
#
#             descrip_couleur
# 0            BLANC BANQUISE
# 1   Carbonschwarz metallise
# 2     NOIR PANTHERE CRISTAL
# 3                     JAUNE
# 4               blanc verni
# 5       Saphirschwarz Metal
# 6          gris clair metal
# 7                      Gris
# 8                      brun
# 9                      NOIR
# 10             BLANC NEVADA
# 11              noir metal
# 12         Gris Foncé Métal
# 13         gris clair metal
# 14              Non codifie
# 15                    blanc
# 16           GRIS ALUMINIUM
# 17               noir metal
# 18                    blanc
# 19               Gris Foncé
# 20                    Blanc
# 21                     gris
# 22                     bleu
# 23  Saphirschwarz metallise
# 24               Bleu foncé
# 25              NOIR COSMOS
# 26                 GRIS ALU
# 27  Saphirschwarz metallise
# 28                     Gris
# 29                    blanc

# %%
df['Price'].hist()
